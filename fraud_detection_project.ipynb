# %%
Fraud Detection using Transaction Behavior Analysis

This project identifies suspicious transactions based on abnormal spending patterns.

Logic used:
- Transactions above normal threshold flagged
- Behavioral condition (time) added to improve accuracy

Result:
- Reduced alerts from 97 to 81 using refined rules

# %%
import pandas as pd

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['total_bill'].head()
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# Name: total_bill, dtype: float64

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
df['total_bill'] / df['total_bill'].mean()
# Out:
# 0      0.858690
# 1      0.522593
# 2      1.061865
# 3      1.196809
# 4      1.242802
#          ...
# 239    1.467203
# 240    1.373703
# 241    1.145763
# 242    0.900639
# 243    0.949159
# Name: total_bill, Length: 244, dtype: float64

# %%
(df['total_bill'] / df['total_bill'].mean()) > 1.2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 239     True
# 240     True
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'] > df['total_bill'].mean() * 1.2]
# Out:
#      total_bill   tip     sex smoker  day    time  size  amount_ratio  \
# 4         24.59  3.61  Female     No  Sun  Dinner     4      1.242802
# 5         25.29  4.71    Male     No  Sun  Dinner     4      1.278180
# 7         26.88  3.12    Male     No  Sun  Dinner     4      1.358540
# 11        35.26  5.00  Female     No  Sun  Dinner     4      1.782073
# 23        39.42  7.58    Male     No  Sat  Dinner     4      1.992324
# ..          ...   ...     ...    ...  ...     ...   ...           ...
# 230       24.01  2.00    Male    Yes  Sat  Dinner     4      1.213488
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2      1.659259
# 238       35.83  4.67  Female     No  Sat  Dinner     3      1.810882
# 239       29.03  5.92    Male     No  Sat  Dinner     3      1.467203
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2      1.373703
#
#      suspicious
# 4         False
# 5         False
# 7         False
# 11         True
# 23         True
# ..          ...
# ...

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
df[df['total_bill'] > 20]
# Out:
#      total_bill   tip     sex smoker  day    time  size  amount_ratio  \
# 2         21.01  3.50    Male     No  Sun  Dinner     3      1.061865
# 3         23.68  3.31    Male     No  Sun  Dinner     2      1.196809
# 4         24.59  3.61  Female     No  Sun  Dinner     4      1.242802
# 5         25.29  4.71    Male     No  Sun  Dinner     4      1.278180
# 7         26.88  3.12    Male     No  Sun  Dinner     4      1.358540
# ..          ...   ...     ...    ...  ...     ...   ...           ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2      1.659259
# 238       35.83  4.67  Female     No  Sat  Dinner     3      1.810882
# 239       29.03  5.92    Male     No  Sat  Dinner     3      1.467203
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2      1.373703
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2      1.145763
#
#      suspicious
# 2         False
# 3         False
# 4          True
# 5          True
# 7          True
# ..          ...
# ...

# %%
df[df['total_bill'] > 20].head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  amount_ratio  \
# 2       21.01  3.50    Male     No  Sun  Dinner     3      1.061865
# 3       23.68  3.31    Male     No  Sun  Dinner     2      1.196809
# 4       24.59  3.61  Female     No  Sun  Dinner     4      1.242802
# 5       25.29  4.71    Male     No  Sun  Dinner     4      1.278180
# 7       26.88  3.12    Male     No  Sun  Dinner     4      1.358540
#
#    suspicious
# 2        True
# 3        True
# 4        True
# 5        True
# 7        True

# %%
(df['total_bill'] > 20).sum()
# Out:
# 97

# %%
'suspicious' in df.columns
# Out:
# True

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  amount_ratio  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2      0.858690
# 1       10.34  1.66    Male     No  Sun  Dinner     3      0.522593
# 2       21.01  3.50    Male     No  Sun  Dinner     3      1.061865
# 3       23.68  3.31    Male     No  Sun  Dinner     2      1.196809
# 4       24.59  3.61  Female     No  Sun  Dinner     4      1.242802
#
#    suspicious
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True

# %%
df['suspicious'].value_counts()
# Out:
# False    147
# True      97
# Name: suspicious, dtype: int64

# %%
df[df['suspicious'] == True].head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  amount_ratio  \
# 2       21.01  3.50    Male     No  Sun  Dinner     3      1.061865
# 3       23.68  3.31    Male     No  Sun  Dinner     2      1.196809
# 4       24.59  3.61  Female     No  Sun  Dinner     4      1.242802
# 5       25.29  4.71    Male     No  Sun  Dinner     4      1.278180
# 7       26.88  3.12    Male     No  Sun  Dinner     4      1.358540
#
#    suspicious
# 2        True
# 3        True
# 4        True
# 5        True
# 7        True

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df[df['time'] == 'Dinner'].head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  amount_ratio  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2      0.858690
# 1       10.34  1.66    Male     No  Sun  Dinner     3      0.522593
# 2       21.01  3.50    Male     No  Sun  Dinner     3      1.061865
# 3       23.68  3.31    Male     No  Sun  Dinner     2      1.196809
# 4       24.59  3.61  Female     No  Sun  Dinner     4      1.242802
#
#    suspicious  final_flag
# 0       False       False
# 1       False       False
# 2        True        True
# 3        True        True
# 4        True        True

# %%
((df['total_bill'] > 20) & (df['time'] == 'Dinner')).sum()
# Out:
# 81

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  amount_ratio  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2      0.858690
# 1       10.34  1.66    Male     No  Sun  Dinner     3      0.522593
# 2       21.01  3.50    Male     No  Sun  Dinner     3      1.061865
# 3       23.68  3.31    Male     No  Sun  Dinner     2      1.196809
# 4       24.59  3.61  Female     No  Sun  Dinner     4      1.242802
#
#    suspicious  final_flag
# 0       False       False
# 1       False       False
# 2        True        True
# 3        True        True
# 4        True        True

# %%
df['final_flag'].value_counts()
# Out:
# False    163
# True      81
# Name: final_flag, dtype: int64
